# %%
import numpy as np
import pandas as pd

def get_ctrl_file_table(path,make_csv=False):
    '''
    Reads input file_table.csv file and outputs .csv table listing Experiment_accessions for the controls of each target
    Accepts "make_csv" boolean argument if user wants to output table
    '''
    file_table = pd.read_csv(path)
    # print(file_table.columns)
    ctrls = file_table[(file_table['experiment_type'] == "ctrl") & (file_table['mate']==1)]
    hepg2_ctrls = file_table[(file_table['experiment_type'] == "ctrl") & (file_table['mate']==1) & (file_table['cell_line'] == "HepG2")]
    k562_ctrls = file_table[(file_table['experiment_type'] == "ctrl") & (file_table['mate']==1) & (file_table['cell_line'] == "K562")]

    assert len(ctrls) == (len(hepg2_ctrls) + len(k562_ctrls)), "Uncaptured cell line control rows!"

    ctrls = ctrls.loc[:,['target','cell_line','experiment_type','experiment_accession']]
    hepg2_ctrls = hepg2_ctrls.loc[:,['target','cell_line','experiment_type','experiment_accession']]
    k562_ctrls = k562_ctrls.loc[:,['target','cell_line','experiment_type','experiment_accession']]
    
    if make_csv:
        ctrl_output_path = path.replace(".csv","_ctrls.csv")
        hepg2_ctrls_output_path =  path.replace(".csv","_ctrls_hepg2.csv")
        k562_ctrls_output_path = path.replace(".csv","_ctrls_K562.csv")
        
        ctrls.to_csv(ctrl_output_path)
        hepg2_ctrls.to_csv(hepg2_ctrls_output_path)
        k562_ctrls.to_csv(k562_ctrls_output_path)
    return ctrls

def get_multiindex_ctrl_file_table(path,make_csv=False):
    '''
    Reads input file_table.csv file and outputs .csv table listing experiment_accessions for the controls of each target.
    Output .csv file is multiindexed by target + cell_line.
    Accepts "make_csv" boolean argument if user wants to output table
    '''
    file_table = pd.read_csv(path)
    target_table = file_table[(file_table['mate']==1) & (file_table['replicate'] == 1)]
    target_table = target_table.set_index(['target','cell_line'])
    target_table= target_table.loc[:,['experiment_type','experiment_accession']]
    
    if make_csv:
        output_path = path.replace(".csv","_ctrls_multiindex.csv")
        target_table.to_csv(output_path)
    return target_table

if __name__=="__main__":
    get_ctrl_file_table("/Users/lij/PycharmProjects/eclip_analysis_pipeline/file_table.csv",make_csv=True)
    get_multiindex_ctrl_file_table("/Users/lij/PycharmProjects/eclip_analysis_pipeline/file_table.csv",make_csv=True)
# Out:
#                   experiment_type experiment_accession
# target  cell_line
# HNRNPC  HepG2               eclip          ENCSR550DVK
#         HepG2                ctrl          ENCSR497ANA
# RBFOX2  HepG2               eclip          ENCSR987FTF
#         HepG2                ctrl          ENCSR799EKA
# IGF2BP1 HepG2               eclip          ENCSR744GEU
#         HepG2                ctrl          ENCSR205ZCE
# HNRNPK  HepG2               eclip          ENCSR828ZID
#         HepG2                ctrl          ENCSR354KAS
# SRSF7   HepG2               eclip          ENCSR513NDD
#         HepG2                ctrl          ENCSR629MQN
# IGF2BP3 HepG2               eclip          ENCSR993OLA
#         HepG2                ctrl          ENCSR077KVG
# TIA1    HepG2               eclip          ENCSR623VEQ
#         HepG2                ctrl          ENCSR333PZV
# SRSF9   HepG2               eclip          ENCSR773KRC
#         HepG2                ctrl          ENCSR060VZF
# TRA2A   HepG2               eclip          ENCSR314UMJ
#         HepG2                ctrl          ENCSR544CTM
# IGF2BP1 K562                eclip          ENCSR975KIR
#         K562                 ctrl          ENCSR125CLF
# HNRNPM  HepG2               eclip          ENCSR267UCX
#         HepG2                ctrl          ENCSR459ONR
# FKBP4   HepG2               eclip          ENCSR018ZUE
#         HepG2                ctrl          ENCSR704LTK
# HNRNPM  K562                eclip          ENCSR412NOW
#         K562                 ctrl          ENCSR212ILN
# IGF2BP2 K562                eclip          ENCSR062NNB
#         K562                 ctrl          ENCSR387RGT
# SLTM    HepG2               eclip          ENCSR351PVI
#         HepG2                ctrl          ENCSR670UPZ
# ...                           ...                  ...
# YBX3    HepG2               eclip          ENCSR735HOK
#         HepG2                ctrl          ENCSR700UGT
# SSB     HepG2               eclip          ENCSR352STY
#         HepG2                ctrl          ENCSR145ZKN
# ABCF1   K562                eclip          ENCSR089BXO
#         K562                 ctrl          ENCSR857ORY
# ZNF800  K562                eclip          ENCSR586DGV
#         K562                 ctrl          ENCSR615ZYL
# SSB     K562                eclip          ENCSR356MSW
#         K562                 ctrl          ENCSR680HYD
# SDAD1   K562                eclip          ENCSR906ZJF
#         K562                 ctrl          ENCSR155XOS
# ZNF800  HepG2               eclip          ENCSR685AUR
#         HepG2                ctrl          ENCSR624CUX
# SDAD1   HepG2               eclip          ENCSR050BDZ
#         HepG2                ctrl          ENCSR130ZDS
# SAFB    HepG2               eclip          ENCSR337XGI
#         HepG2                ctrl          ENCSR451BRX
#         K562                eclip          ENCSR484LAB
#         K562                 ctrl          ENCSR111USM
# PABPN1  HepG2               eclip          ENCSR820UYE
#         HepG2                ctrl          ENCSR310WYE
# PRPF4   HepG2               eclip          ENCSR977OXG
#         HepG2                ctrl          ENCSR367ACZ
# TIAL1   HepG2               eclip          ENCSR322HHA
#         HepG2                ctrl          ENCSR599YGK
# KHSRP   HepG2               eclip          ENCSR366DGX
#         HepG2                ctrl          ENCSR423QXH
# AQR     HepG2               eclip          ENCSR018WPY
#         HepG2                ctrl          ENCSR716AKC
#
# [452 rows x 2 columns]

# %%
import numpy as np
import pandas as pd
import itertools

file_table = pd.read_csv("/Users/lij/PycharmProjects/eclip_analysis_pipeline/file_table.csv")
# print(file_table.columns)
ctrls = file_table[(file_table['mate']==1) & (file_table['replicate'] == 1)]
hepg2_ctrls = file_table[(file_table['experiment_type'] == "ctrl") & (file_table['mate']==1) & (file_table['cell_line'] == "HepG2")]
k562_ctrls = file_table[(file_table['experiment_type'] == "ctrl") & (file_table['mate']==1) & (file_table['cell_line'] == "K562")]

multi = ctrls.set_index(['target','cell_line'])
multi.loc[:,['experiment_type','experiment_accession']]
# assert len(ctrls) == (len(hepg2_ctrls) + len(k562_ctrls)), "Uncaptured cell line control rows!"

# ctrls = ctrls.loc[:,['target','experiment_type','experiment_accession']]
# hepg2_ctrls = hepg2_ctrls.loc[:,['target','experiment_type','experiment_accession']]
# k562_ctrls = k562_ctrls.loc[:,['target','experiment_type','experiment_accession']]
# ctrls


# ctrls.to_csv("/Users/lij/PycharmProjects/eclip_analysis_pipeline/file_table_ctrls.csv")
# hepg2_ctrls.to_csv("/Users/lij/PycharmProjects/eclip_analysis_pipeline/file_table_hepg2.csv")
# k562_ctrls.to_csv("/Users/lij/PycharmProjects/eclip_analysis_pipeline/file_table_K562.csv")
# Out:
#                   experiment_type experiment_accession
# target  cell_line
# HNRNPC  HepG2               eclip          ENCSR550DVK
#         HepG2                ctrl          ENCSR497ANA
# RBFOX2  HepG2               eclip          ENCSR987FTF
#         HepG2                ctrl          ENCSR799EKA
# IGF2BP1 HepG2               eclip          ENCSR744GEU
#         HepG2                ctrl          ENCSR205ZCE
# HNRNPK  HepG2               eclip          ENCSR828ZID
#         HepG2                ctrl          ENCSR354KAS
# SRSF7   HepG2               eclip          ENCSR513NDD
#         HepG2                ctrl          ENCSR629MQN
# IGF2BP3 HepG2               eclip          ENCSR993OLA
#         HepG2                ctrl          ENCSR077KVG
# TIA1    HepG2               eclip          ENCSR623VEQ
#         HepG2                ctrl          ENCSR333PZV
# SRSF9   HepG2               eclip          ENCSR773KRC
#         HepG2                ctrl          ENCSR060VZF
# TRA2A   HepG2               eclip          ENCSR314UMJ
#         HepG2                ctrl          ENCSR544CTM
# IGF2BP1 K562                eclip          ENCSR975KIR
#         K562                 ctrl          ENCSR125CLF
# HNRNPM  HepG2               eclip          ENCSR267UCX
#         HepG2                ctrl          ENCSR459ONR
# FKBP4   HepG2               eclip          ENCSR018ZUE
#         HepG2                ctrl          ENCSR704LTK
# HNRNPM  K562                eclip          ENCSR412NOW
#         K562                 ctrl          ENCSR212ILN
# IGF2BP2 K562                eclip          ENCSR062NNB
#         K562                 ctrl          ENCSR387RGT
# SLTM    HepG2               eclip          ENCSR351PVI
#         HepG2                ctrl          ENCSR670UPZ
# ...                           ...                  ...
# YBX3    HepG2               eclip          ENCSR735HOK
#         HepG2                ctrl          ENCSR700UGT
# SSB     HepG2               eclip          ENCSR352STY
#         HepG2                ctrl          ENCSR145ZKN
# ABCF1   K562                eclip          ENCSR089BXO
#         K562                 ctrl          ENCSR857ORY
# ZNF800  K562                eclip          ENCSR586DGV
#         K562                 ctrl          ENCSR615ZYL
# SSB     K562                eclip          ENCSR356MSW
#         K562                 ctrl          ENCSR680HYD
# SDAD1   K562                eclip          ENCSR906ZJF
#         K562                 ctrl          ENCSR155XOS
# ZNF800  HepG2               eclip          ENCSR685AUR
#         HepG2                ctrl          ENCSR624CUX
# SDAD1   HepG2               eclip          ENCSR050BDZ
#         HepG2                ctrl          ENCSR130ZDS
# SAFB    HepG2               eclip          ENCSR337XGI
#         HepG2                ctrl          ENCSR451BRX
#         K562                eclip          ENCSR484LAB
#         K562                 ctrl          ENCSR111USM
# PABPN1  HepG2               eclip          ENCSR820UYE
#         HepG2                ctrl          ENCSR310WYE
# PRPF4   HepG2               eclip          ENCSR977OXG
#         HepG2                ctrl          ENCSR367ACZ
# TIAL1   HepG2               eclip          ENCSR322HHA
#         HepG2                ctrl          ENCSR599YGK
# KHSRP   HepG2               eclip          ENCSR366DGX
#         HepG2                ctrl          ENCSR423QXH
# AQR     HepG2               eclip          ENCSR018WPY
#         HepG2                ctrl          ENCSR716AKC
#
# [452 rows x 2 columns]
